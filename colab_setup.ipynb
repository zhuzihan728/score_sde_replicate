# %% [markdown]
# # MLMI4 Colab Setup
# Run each cell in order. Make sure **Runtime > Change runtime type** is set to **GPU**.

# %%
# 1. Clone the repo (skip if already mounted via Drive)
import os

REPO_URL = "https://github.com/YOUR_USERNAME/MLMI4.git"  # <-- change this
REPO_DIR = "MLMI4"

if not os.path.exists(REPO_DIR):
    # !git clone {REPO_URL} {REPO_DIR}

# %cd {REPO_DIR}

# %%
# 2. Install JAX with CUDA support (replaces the cpu-only jax in requirements.txt)
# !pip install -q "jax[cuda12]" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html

# %%
# 3. Install remaining dependencies
# !pip install -q \
    numpy \
    optax \
    flax \
    "orbax-checkpoint<0.11.0" \
    tensorflow \
    tensorflow_hub \
    ml_collections \
    scipy \
    matplotlib \
    importlib-resources \
    tensorflow_datasets \
    Pillow

# %%
# 4. Verify JAX sees the GPU
import jax
print("JAX version:", jax.__version__)
print("Devices:", jax.devices())

# %%
# 5. (Optional) Mount Google Drive to access checkpoints
from google.colab import drive
drive.mount('/content/drive')

# Example: copy a checkpoint from Drive
# CKPT_SRC = "/content/drive/MyDrive/MLMI4/runs/vesde_cont_cifar10/ckpt/190000"
# !mkdir -p runs/vesde_cont_cifar10/ckpt
# !cp -r {CKPT_SRC} runs/vesde_cont_cifar10/ckpt/
